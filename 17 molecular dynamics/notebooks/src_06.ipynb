# %% [markdown]
# # main
#
# Now I have dipole-dipole interactions, and I wanted to play with them. I rotate a $\mathbf{B}$ field around the $y$ axis, and set three particles on the $x$ axis, and now have defined linear interactions with different strengths in an attempt to break reciprocal-motion. I expect to see them vibrate.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import copy
import auxiliary_2 as aux

mpl.rc("figure", dpi=150)
mpl.rc("figure", figsize=(4,4))

plt.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'xtick.labelsize':15,
    'ytick.labelsize':15,
    'axes.labelsize':20,
})

import os
import re

# %reload_ext autoreload
# %autoreload 2

# %%
# extra stuff
from matplotlib.ticker import FormatStrFormatter, ScalarFormatter
import math
from scipy.spatial import cKDTree  # For finding nearest neighbors

# formatting
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-2, 2))  # Sets limits for when to use scientific notation

# %%
# output directory
src_n = 6
dataDir = f'../data.lbm/0{src_n}/'
# dataDir = f'../src/0{src_n}/output.lbm/'

# all ticks are found using regular expressions
files = os.listdir(dataDir)
ticks = []

pattern = r'fluidTrj_(\d+)\.csv'

for file in files:
    match = re.search(pattern, file)
    if match:
        ticks.append(int(match.group(1)))
        
ticks.sort()

len(ticks)
# Out:
# 100

# %% [markdown]
# # Fluid

# %%
id = -1
fluidDf = pd.read_csv(dataDir + f"fluidTrj_{ticks[id]}.csv").set_index(["id_x","id_y"]).sort_index()
particleDf = pd.read_csv(dataDir+"particlesTrj.csv")

# %%
title = f'squirmer-bead-bead, $t = {fluidDf.time.values[-1]:0.1f}$'+' $\\mu \\mathrm{s}$'
fig, axes = aux.fluidOverview(fluidDf, particleDf, title)
plt.show()

# %%
id = 1
fluidDf = pd.read_csv(dataDir + f"fluidTrj_{ticks[id]}.csv").set_index(["id_x","id_y"]).sort_index()
# particleDf = pd.read_csv(dataDir+"particlesTrj.csv")

# %%
title = f'$t = {fluidDf.time.values[-1]:0.1f}$'+' $\\mu \\mathrm{s}$'
fig, axes = aux.fluidOverview(fluidDf, particleDf, title)
plt.show()

# %% [markdown]
# # particles

# %% [markdown]
# Due to the bonds, $\mathbf{r}_{12}$ and $\mathbf{r}_{23}$ must have remained roughly constant. Of course, some variation is acceptable, as well as equilibrium different to the initial conditions; everything's bound by harmonic potentials.
#
# > **Note:** $\mathbf{r}_{ij} \equiv \mathbf{x}_i - \mathbf{x}_j$ is the separation vector between particles $i$ and $j$.

# %%
x1 = [
    particleDf.query("particleId == 1").position_x.values,
    particleDf.query("particleId == 1").position_y.values,
]
x2 = [
    particleDf.query("particleId == 2").position_x.values,
    particleDf.query("particleId == 2").position_y.values,
]
x3 = [
    particleDf.query("particleId == 3").position_x.values,
    particleDf.query("particleId == 3").position_y.values,
]

r12 = [x1[index] - x2[index] for index in np.arange(len(x1))]
r32 = [x3[index] - x2[index] for index in np.arange(len(x2))]

particleTime = particleDf.time.unique()

latticeParameter = fluidDf.coordinate_x.unique()[1] - fluidDf.coordinate_x.unique()[0]
meanDisp = np.sqrt(np.mean(r12[0]**2 + r12[1]**2))
period = 100
periodId = int(np.ceil(period/particleTime[1]-particleTime[0])) # timestep
periodId
# Out:
# 484

# %%
fig, axes = plt.subplots(1,3,figsize=(9,2.7))

axes[0].plot(
    particleTime,
    x1[0]
)
axes[0].set_ylim(-5-latticeParameter, -5+latticeParameter)
axes[0].set_xlabel("$t ~ (\\mu \\mathrm{s})$")
axes[0].set_title("${x}_1 ~ (\\mu \\mathrm{m})$")

axes[1].plot(
    particleTime,
    x2[0]
)
axes[1].set_ylim(-latticeParameter,latticeParameter)
axes[1].set_xlabel("$t ~ (\\mu \\mathrm{s})$")
axes[1].set_title("${x}_2 ~ (\\mu \\mathrm{m})$")

axes[2].plot(
    particleTime,
    x3[0]
)
axes[2].set_ylim(5-latticeParameter, 5+latticeParameter)
axes[2].set_xlabel("$t ~ (\\mu \\mathrm{s})$")
axes[2].set_title("${x}_3 ~ (\\mu \\mathrm{m})$")

plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(9,2.7))

axes[0].plot(
    particleTime[-periodId:],
    x1[0][-periodId:]
)
axes[0].set_ylim(-5-latticeParameter/5, -5+latticeParameter/5)
axes[0].set_xlabel("$t ~ (\\mu \\mathrm{s})$")
axes[0].set_title("${x}_1 ~ (\\mu \\mathrm{m})$")

axes[1].plot(
    particleTime[-periodId:],
    x2[0][-periodId:]
)
axes[1].set_ylim(-latticeParameter/5,latticeParameter/5)
axes[1].set_xlabel("$t ~ (\\mu \\mathrm{s})$")
axes[1].set_title("${x}_2 ~ (\\mu \\mathrm{m})$")

axes[2].plot(
    particleTime[-periodId:],
    x3[0][-periodId:]
)
axes[2].set_ylim(5-latticeParameter/5, 5+latticeParameter/5)
axes[2].set_xlabel("$t ~ (\\mu \\mathrm{s})$")
axes[2].set_title("${x}_3 ~ (\\mu \\mathrm{m})$")

plt.show()

# %% [markdown]
# # Stability analysis

# %%
def avgSpeed(df):
    return np.sqrt(df.fluidVelocity_x**2 + df.fluidVelocity_y**2).mean()

# %%
try:
    avgFluidSpeed 
except NameError:
    avgFluidSpeed = []
    
try:
    time 
except NameError:
    time = []

for tick in ticks[len(time)::]:
    auxDf = pd.read_csv(dataDir + f"fluidTrj_{tick}.csv")
    avgFluidSpeed.append(avgSpeed(auxDf))
    time.append(auxDf.time.values[0])
    print(f'\r{tick}', end='', flush=True)
print('\r'+' '*10, end='', flush=True)

# %%
fig, ax = plt.subplots(figsize = (5,5))

ax.plot(time, avgFluidSpeed)
ax.set_xlabel("$t ~ (\\mu \\mathrm{s})$")
ax.set_ylabel("$|u| ~ (\\mu \\mathrm{m} / \\mu \\mathrm{s})$")

plt.show()

# %% [markdown]
# # Animation

# %%
# necessary directories are created
outputDir = f"frames.{src_n}"
os.system(f'mkdir -p anims')
os.system(f'mkdir {outputDir}')

# the data is read and frames are saved
particleDf = pd.read_csv(dataDir+"particlesTrj.csv")
for tickId in np.arange(len(ticks)):
    fluidDf = pd.read_csv(dataDir + f"fluidTrj_{ticks[tickId]}.csv").set_index(["id_x","id_y"]).sort_index()
    title = f'$t = {fluidDf.time.values[-1]:.0f}$'+' $\\mu \\mathrm{s}$'
    fig, axes = aux.fluidOverview(fluidDf, particleDf, title)

    plt.savefig(f"{outputDir}/{tickId}.png", format="png", dpi=300, bbox_inches="tight")
    plt.close()
    print(f'\r{tickId}', end='', flush=True)
print('\r'+' '*10, end='', flush=True)

# ffmpeg is used to create the animation
mkAnimSh = f'ffmpeg -framerate 10 -i {outputDir}/%d.png -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" -c:v libx264 -pix_fmt yuv420p -loglevel quiet anims/src_0{src_n}.mp4'
os.system(mkAnimSh)

# the directory with the frames is erased
os.system(f'rm -r {outputDir}')
# Out:
# 0
