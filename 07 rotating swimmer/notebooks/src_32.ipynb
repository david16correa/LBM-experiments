# %% [markdown]
# # main
#
# Well, if a 2D disk swims backwards, then a 3D rod should swim backwards as well, right?

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import copy
import auxiliary5 as aux

mpl.rc("figure", dpi=150)
mpl.rc("figure", figsize=(4,4))

plt.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'xtick.labelsize':15,
    'ytick.labelsize':15,
    'axes.labelsize':20,
})

import os
import re

# %reload_ext autoreload
# %autoreload 2

# %%
# extra stuff
from matplotlib.ticker import FormatStrFormatter, ScalarFormatter
import math
from scipy.spatial import cKDTree  # For finding nearest neighbors

# formatting
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-2, 2))  # Sets limits for when to use scientific notation

# %%
# output directory
src_n = 32
# dataDir = f'../data.lbm/{src_n}/'
dataDir = f'../src/{src_n}/output.lbm/'

# all ticks are found using regular expressions
files = os.listdir(dataDir)
ticks = []

pattern = r'fluidTrj_(\d+)\.csv'

for file in files:
    match = re.search(pattern, file)
    if match:
        ticks.append(int(match.group(1)))
        
ticks.sort()

len(ticks)
# Out:
# 6

# %% [markdown]
# # Fluid

# %%
# id += 1
id = -1
fluidDf = pd.read_csv(dataDir + f"fluidTrj_{ticks[id]}.csv").set_index(["id_x","id_y","id_z"]).sort_index()

# %%
minX = fluidDf.query(f"coordinate_x >= {level}").coordinate_x.min()
df = fluidDf.query(f"coordinate_x == {minX}").reset_index().set_index(['id_z','id_y'])
(df.fluidVelocity_x**2 + df.fluidVelocity_y**2 + df.fluidVelocity_z**2).max()
# Out:
# np.float64(7.249029553091276e-13)

# %%
level = 0
title = f"$t = {fluidDf.time.values[0]:.0f}$"+" $\\mu \\mathrm{s},$"+f"$ ~ z \\approx {level}$"+" $\\mu \\mathrm{m}$"
fig, axes = aux.fluidOverviewZ(fluidDf, title, level)
# plt.savefig("figure1.png", format="png", transparent=True, dpi=1000, bbox_inches="tight")
plt.show()

# %%
level = 1
title = f"$t = {fluidDf.time.values[0]:.0f}$"+" $\\mu \\mathrm{s},$"+f"$ ~ x \\approx {level}$"+" $\\mu \\mathrm{m}$"
fig, axes = aux.fluidOverviewX(fluidDf, title, level)
# plt.savefig("figure1.png", format="png", transparent=True, dpi=1000, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Particle

# %% [markdown]
# The box coordinates are $x,y,z \in [-15, 15]$.
#
# The particle is a rod, not a sphere.
#
# The initial position of the particle is $\mathbf{r}_0 = -13.5~\mathbf{\hat{y}}$, and the angular velocity is $\mathrm{\omega} = + \mathbf{\hat{z}}~{\mathrm{rad}}/{\mathrm{s}}$, i.e. It is above to the $xz$ plane, and it rotates such that it should swim towards $-\mathbf{\hat{x}}$. If it is to be consistent with 2D simulations, however, it will swim towards $+\mathbf{\hat{x}}$.

# %%
particleDf = pd.read_csv(dataDir+"particlesTrj.csv")
particleDf.time.array[-1]
# Out:
# np.float64(501.7241379310178)

# %%
fig, axes = aux.particleTrjOverview(particleDf)
plt.show()

# %% [markdown]
# # Stability analysis

# %% [markdown]
# In an effort to verify a stable equilibrium state was achieved, the mean fluid speed is studied as a function of time.

# %%
def avgSpeed(df):
    return np.sqrt(df.fluidVelocity_x**2 + df.fluidVelocity_y**2 + df.fluidVelocity_z**2).mean()

# %%
try:
    avgFluidSpeed 
except NameError:
    avgFluidSpeed = []
    
try:
    time 
except NameError:
    time = []

for tick in ticks[len(time)::]:
    print(f'\r{tick}', end='', flush=True)
    auxDf = pd.read_csv(dataDir + f"fluidTrj_{tick}.csv")
    avgFluidSpeed.append(avgSpeed(auxDf))
    time.append(auxDf.time.values[0])
print('\r'+' '*10, end='', flush=True)

# %%
fig, ax = plt.subplots(figsize = (5,5))

ax.plot(time, avgFluidSpeed)
ax.set_xlabel("$t ~ (\\mu \\mathrm{s})$")
ax.set_ylabel("$|u| ~ (\\mu \\mathrm{m} / \\mu \\mathrm{s})$")

plt.show()

# %% [markdown]
# # Animation

# %%
# necessary directories are created
outputDir = f"frames.{src_n}"
os.system(f'mkdir -p anims')
os.system(f'mkdir -p {outputDir}/x')
os.system(f'mkdir -p {outputDir}/z')

# the data is read and frames are saved
fluidDf = pd.read_csv(dataDir + f"fluidTrj_{ticks[-1]}.csv").set_index(["id_x","id_y","id_z"]).sort_index()
c = 0
for level in np.arange(-15,15.25,0.25):
    print(f'\r{level}', end='', flush=True)
    c+=1
    
    title = f"$x \\approx {level:.2f}$"+" $\\mu \\mathrm{m}$"
    fig, axes = aux.fluidOverviewX(fluidDf, title, level)
    plt.savefig(f"{outputDir}/x/{c}.png", format="png", dpi=300, bbox_inches="tight")
    plt.close()
    
    title = f"$z \\approx {level:.2f}$"+" $\\mu \\mathrm{m}$"
    fig, axes = aux.fluidOverviewZ(fluidDf, title, level)
    plt.savefig(f"{outputDir}/z/{c}.png", format="png", dpi=300, bbox_inches="tight")
    plt.close()

print('\r'+' '*10, end='', flush=True)

# ffmpeg is used to create the animation
mkAnimSh = f'ffmpeg -framerate 15 -i {outputDir}/x/%d.png -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" -c:v libx264 -pix_fmt yuv420p -loglevel quiet anims/src_{src_n}_x.mp4'
os.system(mkAnimSh)
mkAnimSh = f'ffmpeg -framerate 15 -i {outputDir}/z/%d.png -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" -c:v libx264 -pix_fmt yuv420p -loglevel quiet anims/src_{src_n}_z.mp4'
os.system(mkAnimSh)

# the directory with the frames is erased
os.system(f'rm -r {outputDir}')
